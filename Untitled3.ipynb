# %%
a=10
a
# Out:
# 10

# %%
b =10
a+b
# Out:
# 20

# %% [markdown]
# # python basic

# %%
a=input("enter the value : ")
b=input("2nd value : ")
print(a+b)
# Out:
# enter the value : hii
# 2nd value :  ana
# hii  ana

# %%
a=int(input('enter int val '))
print(a)
# Out:
# enter int val 9.8
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-811d91f644db> in <module>
# ----> 1 a=int(input('enter int val '))
#       2 print(a)
#
# ValueError: invalid literal for int() with base 10: '9.8'

# %%
a=int(input('enter int val '))
print(a)
# Out:
# enter int val 9.8
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-811d91f644db> in <module>
# ----> 1 a=int(input('enter int val '))
#       2 print(a)
#
# ValueError: invalid literal for int() with base 10: '9.8'

# %%
# user defined function
# in-built function
# lambda function

# %%
# user def
def check_even(a):
    if(a%2==0):
        print('yes')
    else:
        print('no')
check_even(6)
# Out:
# yes

# %%
x = 90
y = 99
print("x : ",x)
print("y : ",y)
print(x,y)
# Out:
# x :  90
# y :  99
# 90 99

# %%
# default argument
def myfun(p,q=90):
    return p*p
myfun(2)

# %%
# keyword argument function
def emp(fname,lname):
    print(fname,lname)
emp(lname="anc",fname="q")
# Out:
# anc q

# %%
l=[1,2,3,4]
t=(3,3)
s={4,5,5}

print("t",type(t))
print("l",type(l))
print("s",type(s))
s
# Out:
# t <class 'tuple'>
# l <class 'list'>
# s <class 'set'>
# {4, 5}

# %%
# built in functon
# append
# insert(val)
# remove(val)
# del
# pop(index)
# bin(val)
# bool(val)

# %%
# lambda function : anonynmous function,oneline function
# syntax : func_name = lambda arguments : task/operation
adder = lambda a,b,c:a+b+c
adder(2,3,4)
# Out:
# 9

# %%
import numpy as np
a = np.array([1,2,3])
print(a)
# Out:
# [1 2 3]

# %%
b = np.array([[1,2,3],[1,2,3]])

# %%
# gives 
# ?np.array

# %%
np.ones((4,5),dtype )

# %%
import numpy as np
a = np.array([[2,3,4],[4,6,7]])
print(a.shape)
# Out:
# (2, 3)

# %%
a.size
# Out:
# 6

# %%
a.ndim
# Out:
# 2

# %%
a.reshape(6,1)
# Out:
# array([[2],
#        [3],
#        [4],
#        [4],
#        [6],
#        [7]])

# %%
a.reshape(3,2)
# Out:
# array([[2, 3],
#        [4, 4],
#        [6, 7]])

# %%
d= np.array([[1,2,3,4],[2,3,5,5],[7,8,9,5]])
print(d.size)
# Out:
# 12

# %%
a1 = np.arange(24,dtype=float)
print(a1.dtype)
# Out:
# float64

# %%
np.sum(d)
# gives sun
# Out:
# 54

# %%
# ?np.sum

# %%
np.sum([[2,3],[4,5]])
# Out:
# 14

# %%
np.sum([[2,3],[4,5]],axis=0)
# add 2+4 and 3+5
# similarly 2+3 & 4+5
# Out:
# array([6, 8])

# %%
np.sum([[2,3],[4,5]],axis=1)
# Out:
# array([5, 9])

# %%
b = [1,2,3]
c = [1,4,5]
s = np.equal(b,c)
print(s)
# compares b[0] & c[0],,b[1] & c[1] and goes
# Out:
# [ True False False]

# %%
d = np.array([[1,2,3],[3,6,7]])
e = np.array([[5,4,3],[7,5,4]])
r = d*e
# r = d-e
print(r)
# Out:
# [[ 5  8  9]
#  [21 30 28]]

# %%
d[0]
# Out:
# array([1, 2, 3])

# %%
d[1]
# Out:
# array([3, 6, 7])

# %%
d[:1]
# Out:
# array([[1, 2, 3]])

# %%
d[0,1:2]
# Out:
# array([2])

# %%
d[:1]
# Out:
# array([[1, 2, 3]])

# %%
d[0:2]
# Out:
# array([[1, 2, 3],
#        [3, 6, 7]])

# %%
d[1:2]
# Out:
# array([[3, 6, 7]])

# %%
d[,1:]
# Out:
#   File "<ipython-input-40-ae431af81dfc>", line 1
#     d[,1:]
#       ^
# SyntaxError: invalid syntax

# %%
d[0,1:]
# Out:
# array([2, 3])

# %%
d[1,0:2]
# Out:
# array([3, 6])

# %%
d[1,1:2]
# Out:
# array([6])

# %%
d[2:0:-1]
# Out:
# array([[3, 6, 7]])

# %%
(444,679,3)

# %%
d[0:2,1:2]
# Out:
# array([[2],
#        [6]])

# %%
d[0:2,1:]
# Out:
# array([[2, 3],
#        [6, 7]])

# %%
a = np.array([2,4,3])
b = np.array([3,4,5])
np.concatenate((a,b))
# Out:
# array([2, 4, 3, 3, 4, 5])

# %%
np.vstack((a,b))
# Out:
# array([[2, 4, 3],
#        [3, 4, 5]])

# %%
np.column_stack((a,b))
# Out:
# array([[2, 3],
#        [4, 4],
#        [3, 5]])

# %%
np.hstack((a,b))
# Out:
# array([2, 4, 3, 3, 4, 5])

# %%
np.hsplit(a,1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-96fe4a9b3c78> in <module>
# ----> 1 np.hsplit(a,1)
#
# NameError: name 'a' is not defined

# %%
a = np.array([1,2,3,4,5,6,7,8])

# %%
np.hsplit(a,4)
# Out:
# [array([1, 2]), array([3, 4]), array([5, 6]), array([7, 8])]

# %%
# full function 
import numpy as np
def solve(a,b,c):
    a = np.full((a,b),c)
    return a

res = solve(3,3,5)
print(res)
res
# Out:
# [[5 5 5]
#  [5 5 5]
#  [5 5 5]]
# array([[5, 5, 5],
#        [5, 5, 5],
#        [5, 5, 5]])

# %%
res.sum(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-420c70dea115> in <module>
# ----> 1 res.sum(a)
#
# NameError: name 'a' is not defined

# %%
# ?sum

# %%
# ?np.sum

# %%
# adding 2 array of same dimensions
def calculate(a,b):
    s = np.add(a,b)
    return s;
a = np.array([1,2,3])
b = np.array([1,2,3])
result = calculate(a,b)
result
# or simply result = a+b
# Out:
# enter no of elements in list 3

# %%
# ?np.add

# %%
# ?range

# %% [markdown]
# n = int(input('enter no of elements in list '))
# for i in range(n):
#     c = np.array(int(input(np.array([i]))))
# print(c)
# type(c)

# %%
n = int(input('enter no of elements in list '))
for i in range(n):
    c = np.array([int(input(i))])
print(c)
type(c)

# %% [markdown]
# # pandas

# %%
# pandas indexing can have names unlike in numpy indexing starts from 0

# %%
    import pandas as pd
    cars = pd.read_csv("Desktop\mtcars2.csv")

# %%
cars
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
cars.head()
# get 1st 5 records
# Out:
#    S.No         Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0     1          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1     2      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2     3         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3     4     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     5  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
#
#    gear  carb
# 0     4     4
# 1     4     4
# 2     4     1
# 3     3     1
# 4     3     2

# %%
cars.tail(8)
# last records
# Out:
#     S.No        Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 24    25  Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0
# 25    26         Fiat X1-9  27.3    4   79.0   66  4.08  1.935    NaN   1   1
# 26    27     Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 27    28      Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 28    29    Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1
# 29    30      Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1
# 30    31     Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
# 31    32        Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
#
#     gear  carb
# 24     3     2
# 25     4     1
# 26     5     2
# 27     5     2
# 28     5     4
# 29     5     6
# 30     5     8
# 31     4     2

# %%
cars.columns
# Out:
# Index(['S.No', 'Unnamed: 1', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec',
#        'vs', 'am', 'gear', 'carb'],
#       dtype='object')

# %%
cars.shape
# Out:
# (32, 13)

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   S.No        32 non-null     int64
#  1   Unnamed: 1  32 non-null     object
#  2   mpg         32 non-null     float64
#  3   cyl         32 non-null     int64
#  4   disp        32 non-null     float64
#  5   hp          32 non-null     int64
#  6   drat        32 non-null     float64
#  7   wt          32 non-null     float64
#  8   qsec        29 non-null     float64
#  9   vs          32 non-null     int64
#  10  am          32 non-null     int64
#  11  gear        32 non-null     int64
#  12  carb        32 non-null     int64
# dtypes: float64(5), int64(7), object(1)
# memory usage: 3.4+ KB

# %%
cars.mean()
# Out:
# S.No     16.500000
# mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.674828
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64

# %%
cars.median()
# Out:
# S.No     16.500
# mpg      19.200
# cyl       6.000
# disp    196.300
# hp      123.000
# drat      3.695
# wt        3.325
# qsec     17.420
# vs        0.000
# am        0.000
# gear      4.000
# carb      2.000
# dtype: float64

# %%
cars['mpg'].mode()
# Out:
# 0    10.4
# 1    15.2
# 2    19.2
# 3    21.0
# 4    21.4
# 5    22.8
# 6    30.4
# dtype: float64

# %%
# max, min, count
cars.describe()
# Out:
#             S.No        mpg        cyl        disp          hp       drat  \
# count  32.000000  32.000000  32.000000   32.000000   32.000000  32.000000
# mean   16.500000  20.090625   6.187500  230.721875  146.687500   3.596563
# std     9.380832   6.026948   1.785922  123.938694   68.562868   0.534679
# min     1.000000  10.400000   4.000000   71.100000   52.000000   2.760000
# 25%     8.750000  15.425000   4.000000  120.825000   96.500000   3.080000
# 50%    16.500000  19.200000   6.000000  196.300000  123.000000   3.695000
# 75%    24.250000  22.800000   8.000000  326.000000  180.000000   3.920000
# max    32.000000  33.900000   8.000000  472.000000  335.000000   4.930000
#
#               wt       qsec         vs         am       gear     carb
# count  32.000000  29.000000  32.000000  32.000000  32.000000  32.0000
# mean    3.217250  17.674828   0.437500   0.406250   3.687500   2.8125
# std     0.978457   1.780394   0.504016   0.498991   0.737804   1.6152
# ...

# %%
cars = cars.rename(columns={'Unnamed: 1':'model'})

# %%
cars.qsec = cars.qsec.fillna(cars.qsec.mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-b9bd805268fa> in <module>
# ----> 1 cars.qsec = cars.qsec.fillna(cars.qsec.mean())
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11466         if level is not None:
#   11467             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 11468         return self._reduce(
#   11469             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11470         )
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4234                 )
#    4235             with np.errstate(all="ignore"):
# -> 4236                 return op(delegate, skipna=skipna, **kwds)
#    4237
# ...

# %%
cars.describe()
# Out:
#             S.No        mpg        cyl        disp          hp       drat  \
# count  32.000000  32.000000  32.000000   32.000000   32.000000  32.000000
# mean   16.500000  20.090625   6.187500  230.721875  146.687500   3.596563
# std     9.380832   6.026948   1.785922  123.938694   68.562868   0.534679
# min     1.000000  10.400000   4.000000   71.100000   52.000000   2.760000
# 25%     8.750000  15.425000   4.000000  120.825000   96.500000   3.080000
# 50%    16.500000  19.200000   6.000000  196.300000  123.000000   3.695000
# 75%    24.250000  22.800000   8.000000  326.000000  180.000000   3.920000
# max    32.000000  33.900000   8.000000  472.000000  335.000000   4.930000
#
#               wt         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean    3.217250   0.437500   0.406250   3.687500   2.8125
# std     0.978457   0.504016   0.498991   0.737804   1.6152
# min     1.513000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
cars
# Out:
#     S.No                model   mpg  cyl   disp   hp  drat     wt  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440
# 11    12           Merc 450SE  16.4    8  275.8  180  3.07  4.070
# 12    13           Merc 450SL  17.3    8  275.8  180  3.07  3.730
# ...

# %%
cars.qsec = cars.qsec.fillna(cars.qsec.mean
# Out:
#   File "<ipython-input-20-ba019630590a>", line 1
#     cars.qsec = cars.qsec.fillna(cars.qsec.mean
#                                                ^
# SyntaxError: unexpected EOF while parsing

# %%
cars.qsec = cars.qsec.fillna(cars.qsec.mean)

# %%
df = cars.corr()

# %%
df
# Out:
#           S.No       mpg       cyl      disp        hp      drat        wt  \
# S.No  1.000000  0.084699 -0.028882 -0.022048  0.242295  0.240952 -0.162419
# mpg   0.084699  1.000000 -0.852162 -0.847551 -0.776168  0.681172 -0.867659
# cyl  -0.028882 -0.852162  1.000000  0.902033  0.832447 -0.699938  0.782496
# disp -0.022048 -0.847551  0.902033  1.000000  0.790949 -0.710214  0.887980
# hp    0.242295 -0.776168  0.832447  0.790949  1.000000 -0.448759  0.658748
# drat  0.240952  0.681172 -0.699938 -0.710214 -0.448759  1.000000 -0.712441
# wt   -0.162419 -0.867659  0.782496  0.887980  0.658748 -0.712441  1.000000
# vs   -0.109162  0.664039 -0.810812 -0.710416 -0.723097  0.440278 -0.554916
# am    0.354905  0.599832 -0.522607 -0.591227 -0.243204  0.712711 -0.692495
# gear  0.400825  0.480285 -0.492687 -0.555569 -0.125704  0.699610 -0.583287
# carb  0.174576 -0.550925  0.526988  0.394977  0.749812 -0.090790  0.427606
#
#             vs        am      gear      carb
# ...

# %%
cars.mpg = cars.mpg.astype(float)

# %% [markdown]
# # #manipulation

# %%
cars.head(1)
# Out:
#    S.No      model   mpg  cyl   disp   hp  drat    wt   qsec  vs  am  gear  \
# 0     1  Mazda RX4  21.0    6  160.0  110   3.9  2.62  16.46   0   1     4
#
#    carb
# 0     4

# %%
cars.iloc[:,4]
# Out:
# 0     160.0
# 1     160.0
# 2     108.0
# 3     258.0
# 4     360.0
# 5     225.0
# 6     360.0
# 7     146.7
# 8     140.8
# 9     167.6
# 10    167.6
# 11    275.8
# 12    275.8
# 13    275.8
# 14    472.0
# 15    460.0
# 16    440.0
# 17     78.7
# 18     75.7
# 19     71.1
# 20    120.1
# 21    318.0
# 22    304.0
# 23    350.0
# 24    400.0
# 25     79.0
# 26    120.3
# 27     95.1
# 28    351.0
# 29    145.0
# 30    301.0
# 31    121.0
# Name: disp, dtype: float64

# %%
cars.iloc[:,5:7]
# Out:
#      hp  drat
# 0   110  3.90
# 1   110  3.90
# 2    93  3.85
# 3   110  3.08
# 4   175  3.15
# 5   105  2.76
# 6   245  3.21
# 7    62  3.69
# 8    95  3.92
# 9   123  3.92
# 10  123  3.92
# 11  180  3.07
# 12  180  3.07
# 13  180  3.07
# 14  205  2.93
# 15  215  3.00
# 16  230  3.23
# 17   66  4.08
# 18   52  4.93
# 19   65  4.22
# 20   97  3.70
# 21  150  2.76
# 22  150  3.15
# 23  245  3.73
# 24  175  3.08
# 25   66  4.08
# 26   91  4.43
# 27  113  3.77
# 28  264  4.22
# 29  175  3.62
# 30  335  3.54
# 31  109  4.11

# %%
# ?drop
# Out:
# Object `drop` not found.

# %%
# ?drop()
# Out:
# Object `drop()` not found.

# %%
# ?cars.drop()
# Out:
# Object `cars.drop()` not found.

# %%
type(cars)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.drop(['S.No'])
# Out:
#           S.No       mpg       cyl      disp        hp      drat        wt  \
# mpg   0.084699  1.000000 -0.852162 -0.847551 -0.776168  0.681172 -0.867659
# cyl  -0.028882 -0.852162  1.000000  0.902033  0.832447 -0.699938  0.782496
# disp -0.022048 -0.847551  0.902033  1.000000  0.790949 -0.710214  0.887980
# hp    0.242295 -0.776168  0.832447  0.790949  1.000000 -0.448759  0.658748
# drat  0.240952  0.681172 -0.699938 -0.710214 -0.448759  1.000000 -0.712441
# wt   -0.162419 -0.867659  0.782496  0.887980  0.658748 -0.712441  1.000000
# vs   -0.109162  0.664039 -0.810812 -0.710416 -0.723097  0.440278 -0.554916
# am    0.354905  0.599832 -0.522607 -0.591227 -0.243204  0.712711 -0.692495
# gear  0.400825  0.480285 -0.492687 -0.555569 -0.125704  0.699610 -0.583287
# carb  0.174576 -0.550925  0.526988  0.394977  0.749812 -0.090790  0.427606
#
#             vs        am      gear      carb
# mpg   0.664039  0.599832  0.480285 -0.550925
# cyl  -0.810812 -0.522607 -0.492687  0.526988
# ...

# %%
cars['am']=1

# %%
cars
# Out:
#     S.No                model   mpg  cyl   disp   hp  drat     wt  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440
# 11    12           Merc 450SE  16.4    8  275.8  180  3.07  4.070
# 12    13           Merc 450SL  17.3    8  275.8  180  3.07  3.730
# ...
